# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np

# %%
data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
column_names = df.columns
df['target'] = data.target
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
X = df.drop('target', axis=1)
y = df['target']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=42)
# print("Training data shape:", x_train.head())
# print("Testing data shape:", x_test.head())
# print("Training data shape:", y_train.head())
# print("Testing data shape:", y_test.head())
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# lets copy the X_test
x_test_copy = x_test.copy()
x_test_copy['predicted_target'] = y_pred
x_test_copy['actual_target'] = y_test.values

x_test
# Out:
# Accuracy: 1.00
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 73                 6.1               2.8                4.7               1.2
# 18                 5.7               3.8                1.7               0.3
# 118                7.7               2.6                6.9               2.3
# 78                 6.0               2.9                4.5               1.5
# 76                 6.8               2.8                4.8               1.4
# 31                 5.4               3.4                1.5               0.4
# 64                 5.6               2.9                3.6               1.3
# 141                6.9               3.1                5.1               2.3

# %%
# Implement KNN from scratch : not using any library functions : load_iris()
import numpy as np
from collections import Counter
class KNNFromScratch:
    def __init__(self, k=3):
        self.k = k

    def fit(self, X, y):
        self.X_train = X
        self.y_train = y

    def predict(self, X):
        predictions = [self._predict(x) for x in X.to_numpy()]
        return np.array(predictions)

    def _predict(self, x):
        # Compute distances between x and all examples in the training set
        distances = np.linalg.norm(self.X_train.to_numpy() - x, axis=1)
        # Sort by distance and return indices of the first k neighbors
        k_indices = np.argsort(distances)[:self.k]
        # Extract the labels of the k nearest neighbor
        k_nearest_labels = [self.y_train.iloc[i] for i in k_indices]
        # Return the most common class label
        most_common = Counter(k_nearest_labels).most_common(1)
        return most_common[0][0]
knn_scratch = KNNFromScratch(k=3)
knn_scratch.fit(x_train, y_train)
y_pred_scratch = knn_scratch.predict(x_test)
accuracy_scratch = accuracy_score(y_test, y_pred_scratch)
print(f"Accuracy from scratch: {accuracy_scratch:.2f}")
# Out:
# Accuracy from scratch: 1.00

# %%
# new_flower = [5.1,3.5,1.4,0.2]
# knn_predict(df, new_flower, k=5) # take this as a assignment

def class_label(val):
    if val == 0:
        return 'Setosa'
    elif val == 1:
        return 'Versicolor'
    else:
        return 'Virginica'

def euclidean_distance(df, points, column_names):
    distances = []
    for index, row in df.iterrows():
        sum_of_vectors = sum([((row[col_name[1]] - points[col_name[0]])**2) for col_name in enumerate(column_names, start=0)])
        distances.append(np.sqrt(sum_of_vectors))
    return distances
    
def knn_predict(df, new_point, column_names, k):
    df['Distance'] = euclidean_distance(df, new_point, column_names)
    top_k = df.nsmallest(k, 'Distance')
    predicted_status = class_label(top_k['target'].mode()[0])
    return predicted_status

new_flower = [8.1,9.5,5.4,9.2]
knn_predict(df, new_flower, column_names, 5)
# Out:
# 'Virginica'
