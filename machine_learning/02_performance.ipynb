# %%
import pandas as pd
y_actual = pd.Series([1, 0, 1, 1, 0, 1])
y_predicted = pd.Series([1, 0, 1, 0, 0, 1])

# accuracy
accuracy = (y_actual == y_predicted).mean()
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.83

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

# %%
# for confusion matrix
conf_matrix = confusion_matrix(y_actual, y_predicted)
print("Confusion Matrix:")
print(conf_matrix)

# plot it to heatmap
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
# [[2 0]
#  [1 3]]

# %%
# precision
precision = precision_score(y_actual, y_predicted)
print(f"Precision: {precision:.2f}")

# recall
recall = recall_score(y_actual, y_predicted)
print(f"Recall: {recall:.2f}")

# F1 score
f1 = f1_score(y_actual, y_predicted)
print(f"F1 Score: {f1:.2f}")
# Out:
# Precision: 1.00
# Recall: 0.75
# F1 Score: 0.86

# %%
from sklearn.metrics import classification_report

report = classification_report(y_actual, y_predicted)
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       1.00      0.75      0.86         4
#
#     accuracy                           0.83         6
#    macro avg       0.83      0.88      0.83         6
# weighted avg       0.89      0.83      0.84         6

# %%
# Assignment :
# Implement confusion matrix, precision, recall, F1 score from scratch
# create two variable - y_pred, y_actual
y_actual = [1, 0, 1, 1, 0, 1]
y_pred = [1, 0, 1, 0, 0, 1]

# %%
from sklearn.metrics import log_loss,accuracy_score

y_actual = [1, 0, 1, 1, 0, 1]
y_pred = [0.9, 0.1, 0.8, 0.7, 0.2, 0.6]
y_labels_pred = [1, 0, 1, 1, 0, 1]

log_loss_value = log_loss(y_actual, y_pred)
print(f"Log Loss: {log_loss_value:.2f}")

accuracy = accuracy_score(y_actual, y_labels_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Log Loss: 0.25
# Accuracy: 1.00

# %%
y_actual = [1, 0, 1, 1, 0, 1]
y_pred = [0.6, 0.4, 0.6, 0.55, 0.45, 0.50]
y_labels_pred = [1, 0, 1, 1, 0, 1]

log_loss_value = log_loss(y_actual, y_pred)
print(f"Log Loss: {log_loss_value:.2f}")
accuracy = accuracy_score(y_actual, y_labels_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Log Loss: 0.57
# Accuracy: 1.00
