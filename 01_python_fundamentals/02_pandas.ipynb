# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, 30, 22, 35],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}

df = pd.DataFrame(data)
df.head()
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   35      Houston

# %%
reviews = pd.read_csv('reviews.csv')
reviews.tail(2)
# Out:
#             Id   ProductId          UserId              ProfileName  \
# 568452  568453  B004I613EE   A3IBEVCTXKNOH  Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                 srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 568452                     1                       1      5  1331596800
# 568453                     0                       0      5  1338422400
#
#                                    Summary  \
# 568452  Favorite Training and reward treat
# 568453                         Great Honey
#
#                                                      Text
# 568452  These are the BEST treats for training and rew...
# 568453  I am very satisfied ,product is as advertised,...

# %%
reviews.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
reviews.shape
# Out:
# (568454, 10)

# %%
type(reviews)
# Out:
# pandas.core.frame.DataFrame

# %%
# slect col1 ,col 2 from reviews
reviews[['ProductId', 'UserId']].head(4)
# Out:
#     ProductId          UserId
# 0  B001E4KFG0  A3SGXH7AUHU8GW
# 1  B00813GRG4  A1D87F6ZCVE5NK
# 2  B000LQOCH0   ABXLMWJIXXAIN
# 3  B000UA0QIQ  A395BORC6FGVXV

# %%
reviews[reviews['Score'] < 3].shape
# Out:
# (82037, 10)

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      568454 non-null  int64
#  1   ProductId               568454 non-null  object
#  2   UserId                  568454 non-null  object
#  3   ProfileName             568428 non-null  object
#  4   HelpfulnessNumerator    568454 non-null  int64
#  5   HelpfulnessDenominator  568454 non-null  int64
#  6   Score                   568454 non-null  int64
#  7   Time                    568454 non-null  int64
#  8   Summary                 568427 non-null  object
#  9   Text                    568454 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %%
simple_data = {
    'product_category': ['Book', 'Book', 'Electronics', 'Clothing', 'Electronics'],
    'price': [12.99, 15.49, 199.99, 29.99, 99.99],
    'rating': [4.5, 4.0, 3.5, 5.0, 4.2]
}

df_simple = pd.DataFrame(simple_data)
df_simple.head()
# Out:
#   product_category   price  rating
# 0             Book   12.99     4.5
# 1             Book   15.49     4.0
# 2      Electronics  199.99     3.5
# 3         Clothing   29.99     5.0
# 4      Electronics   99.99     4.2

# %%
df_simple['discounted_price'] = df_simple['price'] * 0.9
df_simple.head()
# Out:
#   product_category   price  rating  discounted_price
# 0             Book   12.99     4.5            11.691
# 1             Book   15.49     4.0            13.941
# 2      Electronics  199.99     3.5           179.991
# 3         Clothing   29.99     5.0            26.991
# 4      Electronics   99.99     4.2            89.991

# %%
df_simple['pct_change_in_price']=df_simple['price'].pct_change()
df_simple.head()
# Out:
#   product_category   price  rating  discounted_price  pct_change_in_price
# 0             Book   12.99     4.5            11.691                  NaN
# 1             Book   15.49     4.0            13.941             0.192456
# 2      Electronics  199.99     3.5           179.991            11.910910
# 3         Clothing   29.99     5.0            26.991            -0.850043
# 4      Electronics   99.99     4.2            89.991             2.334111

# %%
df_simple.product_category.value_counts()
# Out:
# product_category
# Book           2
# Electronics    2
# Clothing       1
# Name: count, dtype: int64

# %%
reviews['ProductId'].value_counts()
# Out:
# ProductId
# B007JFMH8M    913
# B0026RQTGE    632
# B002QWHJOU    632
# B002QWP89S    632
# B002QWP8H0    632
#              ...
# B004DSPTTM      1
# B008C9QWU8      1
# B007O5A6BM      1
# B003Q4TZ08      1
# B001LR2CU2      1
# Name: count, Length: 74258, dtype: int64

# %%
reviews[reviews['ProductId']=='B0026RQTGE'].shape
# Out:
# (632, 10)

# %%
df_simple.price.describe()
# Out:
# count      5.0000
# mean      71.6900
# std       80.0075
# min       12.9900
# 25%       15.4900
# 50%       29.9900
# 75%       99.9900
# max      199.9900
# Name: price, dtype: float64

# %%
df_simple.describe(include='all',percentiles=[0.30,0.75, 0.99])  # include all data types
# Out:
#        product_category     price    rating  discounted_price
# count                 5    5.0000  5.000000           5.00000
# unique                3       NaN       NaN               NaN
# top                Book       NaN       NaN               NaN
# freq                  2       NaN       NaN               NaN
# mean                NaN   71.6900  4.240000          64.52100
# std                 NaN   80.0075  0.559464          72.00675
# min                 NaN   12.9900  3.500000          11.69100
# 30%                 NaN   18.3900  4.040000          16.55100
# 50%                 NaN   29.9900  4.200000          26.99100
# 75%                 NaN   99.9900  4.500000          89.99100
# 99%                 NaN  195.9900  4.980000         176.39100
# max                 NaN  199.9900  5.000000         179.99100

# %%
df_simple
# Out:
#   product_category   price  rating
# 0             Book   12.99     4.5
# 1             Book   15.49     4.0
# 2      Electronics  199.99     3.5
# 3         Clothing   29.99     5.0
# 4      Electronics   99.99     4.2

# %%
df_simple.product_category.describe()
# Out:
# count        5
# unique       3
# top       Book
# freq         2
# Name: product_category, dtype: object

# %%
df_simple.to_csv('simple_data.csv', index=False)
df_simple.to_excel('simple_data.xlsx', index=False)
df_simple.to_json('simple_data.json', index=False)
df_simple.to_html('simple_data.html', index=False)

# %%
url = (
    "https://raw.githubusercontent.com/pandas-dev"
    "/pandas/main/pandas/tests/io/data/csv/tips.csv"
)

tips = pd.read_csv(url)
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['new_total_bill'] = tips['total_bill'] - 2
# Out:
#    total_bill   tip     sex smoker  day    time  size  new_total_bill
# 0       16.99  1.01  Female     No  Sun  Dinner     2           14.99
# 1       10.34  1.66    Male     No  Sun  Dinner     3            8.34
# 2       21.01  3.50    Male     No  Sun  Dinner     3           19.01
# 3       23.68  3.31    Male     No  Sun  Dinner     2           21.68
# 4       24.59  3.61  Female     No  Sun  Dinner     4           22.59

# %%
condition = ( tips['day'] == 'Sun') & (tips['new_total_bill'] > 20)
tips[condition]
# Out:
#      total_bill   tip     sex smoker  day    time  size  new_total_bill
# 3         23.68  3.31    Male     No  Sun  Dinner     2           21.68
# 4         24.59  3.61  Female     No  Sun  Dinner     4           22.59
# 5         25.29  4.71    Male     No  Sun  Dinner     4           23.29
# 7         26.88  3.12    Male     No  Sun  Dinner     4           24.88
# 11        35.26  5.00  Female     No  Sun  Dinner     4           33.26
# 44        30.40  5.60    Male     No  Sun  Dinner     4           28.40
# 46        22.23  5.00    Male     No  Sun  Dinner     2           20.23
# 47        32.40  6.00    Male     No  Sun  Dinner     4           30.40
# 48        28.55  2.05    Male     No  Sun  Dinner     3           26.55
# 52        34.81  5.20  Female     No  Sun  Dinner     4           32.81
# 54        25.56  4.34    Male     No  Sun  Dinner     4           23.56
# 112       38.07  4.00    Male     No  Sun  Dinner     3           36.07
# 113       23.95  2.55    Male     No  Sun  Dinner     2           21.95
# 114       25.71  4.00  Female     No  Sun  Dinner     3           23.71
# 116       29.93  5.07    Male     No  Sun  Dinner     4           27.93
# 153       24.55  2.00    Male     No  Sun  Dinner     4           22.55
# 155       29.85  5.14  Female     No  Sun  Dinner     5           27.85
# 156       48.17  5.00    Male     No  Sun  Dinner     6           46.17
# 157       25.00  3.75  Female     No  Sun  Dinner     4           23.00
# 165       24.52  3.48    Male     No  Sun  Dinner     3           22.52
# 167       31.71  4.50    Male     No  Sun  Dinner     4           29.71
# 173       31.85  3.18    Male    Yes  Sun  Dinner     2           29.85
# 175       32.90  3.11    Male    Yes  Sun  Dinner     2           30.90
# 179       34.63  3.55    Male    Yes  Sun  Dinner     2           32.63
# 180       34.65  3.68    Male    Yes  Sun  Dinner     4           32.65
# 181       23.33  5.65    Male    Yes  Sun  Dinner     2           21.33
# 182       45.35  3.50    Male    Yes  Sun  Dinner     3           43.35
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4           21.17
# 184       40.55  3.00    Male    Yes  Sun  Dinner     2           38.55
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5           28.46
# 189       23.10  4.00    Male    Yes  Sun  Dinner     3           21.10

# %%
def bucket_tip(tip):
    if tip < 10:
        return 'Low'
    return 'High'


tips['tip_bucket'] = tips['tip'].apply(bucket_tip)
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  new_total_bill  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2           14.99
# 1       10.34  1.66    Male     No  Sun  Dinner     3            8.34
# 2       21.01  3.50    Male     No  Sun  Dinner     3           19.01
# 3       23.68  3.31    Male     No  Sun  Dinner     2           21.68
# 4       24.59  3.61  Female     No  Sun  Dinner     4           22.59
#
#   tip_bucket
# 0        Low
# 1        Low
# 2        Low
# 3        Low
# 4        Low

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total_bill      244 non-null    float64
#  1   tip             244 non-null    float64
#  2   sex             244 non-null    object
#  3   smoker          244 non-null    object
#  4   day             244 non-null    object
#  5   time            244 non-null    object
#  6   size            244 non-null    int64
#  7   new_total_bill  244 non-null    float64
#  8   tip_bucket      244 non-null    object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 17.3+ KB

# %%
tips.isnull().sum()
# Out:
# total_bill        0
# tip               0
# sex               0
# smoker            0
# day               0
# time              0
# size              0
# new_total_bill    0
# tip_bucket        0
# dtype: int64

# %%
test_df = pd.DataFrame({
    'A': [1, 2, None, 4],
    'B': [None, 2, 3, 4],
    'C': [1, None, None, 4]
})
test_df.head()
# Out:
#      A    B    C
# 0  1.0  NaN  1.0
# 1  2.0  2.0  NaN
# 2  NaN  3.0  NaN
# 3  4.0  4.0  4.0

# %%
test_df.isnull().sum()
# Out:
# A    1
# B    1
# C    2
# dtype: int64

# %%
# https://pandas.pydata.org/docs/getting_started/comparison/comparison_with_spreadsheets.html#compare-with-spreadsheets

# %%
car_df = pd.read_csv('car_price_dataset_medium.csv')

# %%
car_df.rename(columns={'Price_USD': 'Price'}, inplace=True)
car_df.head()
# Out:
#    Car_ID     Brand  Model_Year  Kilometers_Driven Fuel_Type Transmission  \
# 0       1      Audi        2005             197018    Diesel       Manual
# 1       2       BMW        2019              43467    Hybrid    Automatic
# 2       3       Kia        2012             153697    Hybrid    Automatic
# 3       4  Mercedes        2015              38893    Petrol    Automatic
# 4       5      Audi        2016              81329    Hybrid    Automatic
#
#   Owner_Type  Engine_CC  Max_Power_bhp  Mileage_kmpl  Seats      Price
# 0      First       4046          223.6         29.61      6  119611.94
# 1      First       3731          248.4         21.66      5   90842.46
# 2      Third       4925          465.5         12.14      6   78432.24
# 3     Second       3771          229.7         19.65      6   44568.89
# 4      First       2817          573.2          7.74      5    8751.82

# %%
# car_df.head()

# car_df.head()
# car_df.Brand.value_counts()
car_df.groupby('Brand').agg({
    'Price': ['mean', 'min', 'max'],
})
# Out:
#                    Price                     Kilometers_Driven
#                     mean      min        max              mean    min     max
# Brand
# Audi        62351.394043  3353.44  119611.94     103320.542553  11304  197699
# BMW         54154.605532  3048.00  119074.79     103444.202128   5781  199812
# Ford        59953.021364  5446.41  119533.50     102223.272727   5207  199718
# Honda       57226.331687  3435.20  118306.32     101564.807229   8191  199018
# Hyundai     58818.596354  5572.42  119200.16     107235.135417   7659  197660
# Kia         56090.171700  4248.40  117194.36     105549.220000   5587  197404
# Mercedes    64344.239907  3092.37  119331.69     103746.560748   5163  199442
# Nissan      64089.937473  3274.65  119508.88      92807.076923   7336  198718
# Toyota      58964.422288  4522.19  118626.67     103632.771186   5155  195546
# Volkswagen  55987.339720  3028.42  119485.69     108993.093458   8754  199509

# %%
report = car_df.groupby(['Brand','Fuel_Type']).agg({
    'Price': ['mean', 'min', 'max'],
    'Kilometers_Driven': ['mean', 'min', 'max']

})

report.reset_index()
# change the cells color where value > 50000
report
# Out:
#                              Price                      Kilometers_Driven  \
#                               mean       min        max              mean
# Brand      Fuel_Type
# Audi       Diesel     53277.218333   6647.46  119611.94     101066.111111
#            Electric   66219.721786   7718.63  117780.45     108908.928571
#            Hybrid     51630.635000   4853.05  108995.44      98900.000000
#            Petrol     70617.915667   3353.44  118402.94     102109.700000
# BMW        Diesel     48959.442000   6623.56  119074.79     100845.360000
#            Electric   54149.664737   3794.22  107571.58     114889.842105
#            Hybrid     58269.813529   3048.00  117970.33      98785.941176
#            Petrol     55973.224545   4081.27  113459.09     101222.818182
# Ford       Diesel     68400.834800  14579.33  115351.16     100745.720000
#            Electric   61466.326000   9612.34  117485.20     107817.866667
#            Hybrid     58267.564483   5446.41  119533.50      84362.206897
#            Petrol     51963.935769   8165.03  102004.68     117110.653846
# Honda      Diesel     52425.412857   3435.20  113093.00      94958.142857
#            Electric   53512.097143   3988.83  105829.09     116963.500000
#            Hybrid     71787.621429  32507.68  107608.69     103744.714286
#            Petrol     56580.663333   5597.73  118306.32      99301.333333
# Hyundai    Diesel     61928.550000   9473.89  113992.53     115716.000000
#            Electric   58432.903462   8237.90  117735.84      97195.884615
#            Hybrid     59517.330690   7071.51  117136.70     114020.689655
#            Petrol     55369.341429   5572.42  119200.16     102217.142857
# Kia        Diesel     61106.624545   4248.40  114842.50     104005.954545
#            Electric   49418.496296   4412.18  103893.19     108452.962963
#            Hybrid     58292.231538   5853.75  117194.36     106411.576923
#            Petrol     56590.960400   5589.73  113535.76     102874.400000
# Mercedes   Diesel     57420.207241   9089.36  114194.43      99399.655172
#            Electric   63856.970000   7166.62  119331.69      83433.956522
#            Hybrid     62423.763571   3092.37  115230.55     121419.428571
#            Petrol     74187.850741   4754.82  116927.88     107391.370370
# Nissan     Diesel     54568.085000   6606.48  108656.93     118871.416667
#            Electric   57270.161923   4595.86  114947.32      82736.076923
#            Hybrid     73774.305862   4076.51  112611.85     105457.000000
#            Petrol     64537.008750   3274.65  119508.88      75399.833333
# Toyota     Diesel     58689.083182   4522.19  116264.48     102730.000000
#            Electric   67885.625161  10605.09  116857.93     108034.258065
#            Hybrid     53863.721765   5109.75  118626.67     107561.852941
#            Petrol     55832.938065   4738.17  108473.84      95562.645161
# Volkswagen Diesel     59495.049583   6412.97  116750.88     131835.333333
#            Electric   61603.096071   4348.54  116846.31     106374.500000
#            Hybrid     57499.526429   5633.01  117201.16     105053.821429
#            Petrol     45477.434444   3028.42  119485.69      95489.629630
#
#
#                         min     max
# Brand      Fuel_Type
# Audi       Diesel     11304  197018
#            Electric   25074  197699
#            Hybrid     12099  195736
#            Petrol     14686  189816
# BMW        Diesel      6283  195135
#            Electric   23313  199812
#            Hybrid     19849  170575
#            Petrol      5781  198783
# Ford       Diesel      5207  192598
#            Electric   21456  199718
#            Hybrid     10906  196703
#            Petrol     30169  195747
# Honda      Diesel     11910  190378
#            Electric   11548  168856
#            Hybrid      8191  197402
#            Petrol     10901  199018
# Hyundai    Diesel     23099  190165
#            Electric    9135  197660
#            Hybrid     10075  194351
#            Petrol      7659  184402
# Kia        Diesel      5587  197404
#            Electric   15749  194784
#            Hybrid      9895  186801
#            Petrol     10782  177395
# Mercedes   Diesel      5163  190413
#            Electric   10469  199442
#            Hybrid     10347  193978
#            Petrol     17109  185217
# Nissan     Diesel      8471  197035
#            Electric   11721  193785
#            Hybrid      7336  195237
#            Petrol     11710  198718
# Toyota     Diesel     13706  191186
#            Electric    8631  184830
#            Hybrid     23708  195546
#            Petrol      5155  191368
# Volkswagen Diesel     18428  199509
#            Electric   22073  197630
#            Hybrid      8754  192921
#            Petrol     14283  183313

# %%
car_df.head()
# Out:
#    Car_ID     Brand  Model_Year  Kilometers_Driven Fuel_Type Transmission  \
# 0       1      Audi        2005             197018    Diesel       Manual
# 1       2       BMW        2019              43467    Hybrid    Automatic
# 2       3       Kia        2012             153697    Hybrid    Automatic
# 3       4  Mercedes        2015              38893    Petrol    Automatic
# 4       5      Audi        2016              81329    Hybrid    Automatic
#
#   Owner_Type  Engine_CC  Max_Power_bhp  Mileage_kmpl  Seats      Price
# 0      First       4046          223.6         29.61      6  119611.94
# 1      First       3731          248.4         21.66      5   90842.46
# 2      Third       4925          465.5         12.14      6   78432.24
# 3     Second       3771          229.7         19.65      6   44568.89
# 4      First       2817          573.2          7.74      5    8751.82

# %%
# I want to compare  avg price of cars based on Owner_type, Fuel_Type
report = car_df.groupby(['Owner_Type','Fuel_Type']).agg({
    'Price': ['mean', 'min', 'max'],
    'Kilometers_Driven': ['mean', 'min', 'max']
})
import matplotlib.pyplot as plt
# plot owner type vs avg price
report.reset_index().plot(x='Fuel_Type', y=('Price','mean'), kind='bar')
# Out:
# <Axes: xlabel='Fuel_Type'>

# %%
# https://www.quora.com/What-is-the-difference-between-INNER-JOIN-LEFT-JOIN-and-RIGHT-JOIN-in-SQL-and-when-would-you-use-each-one

# %%
products = pd.DataFrame({
    'Prd_id': [1, 2, 3, 4],
    'ProductName': ['Laptop', 'Smartphone', 'Tablet', 'Monitor']
})

orders = pd.DataFrame({
    'OrderID': [101, 102, 103, 104],
    'ProductID': [1, 2, 2, 5],
    'Quantity': [1, 2, 1, 4]
})

# left join
left_join = pd.merge(orders, products, left_on='ProductID', right_on='Prd_id', how='left')
left_join
# Out:
#    OrderID  ProductID  Quantity  Prd_id ProductName
# 0      101          1         1     1.0      Laptop
# 1      102          2         2     2.0  Smartphone
# 2      103          2         1     2.0  Smartphone
# 3      104          5         4     NaN         NaN

# %%
df1 = pd.DataFrame(
    {
        "Price": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)


df2 = pd.DataFrame(
    {
        "Price": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
        "C": ["C4", "C5", "C6", "C7"],
        "D": ["D4", "D5", "D6", "D7"],
    },
    index=[4, 5, 6, 7],
)


df3 = pd.DataFrame(
    {
        "Age": ["A8", "A9", "A10", "A11"],
        "B": ["B8", "B9", "B10", "B11"],
        "C": ["C8", "C9", "C10", "C11"],
        "D": ["D8", "D9", "D10", "D11"],
    },
    index=[8, 9, 10, 11],
)
result = pd.concat([df1, df2, df3],axis=0)
result

# 0 means row-wise/index concatenation
# 1 means column-wise concatenation

# change the cells color where value > 50
# Out:
#    Price    B    C    D  Age
# 0     A0   B0   C0   D0  NaN
# 1     A1   B1   C1   D1  NaN
# 2     A2   B2   C2   D2  NaN
# 3     A3   B3   C3   D3  NaN
# 4     A4   B4   C4   D4  NaN
# 5     A5   B5   C5   D5  NaN
# 6     A6   B6   C6   D6  NaN
# 7     A7   B7   C7   D7  NaN
# 8    NaN   B8   C8   D8   A8
# 9    NaN   B9   C9   D9   A9
# 10   NaN  B10  C10  D10  A10
# 11   NaN  B11  C11  D11  A11

# %%
car_df.head()
print('columns available:', car_df.columns.tolist())
car_df.isnull().sum()
# Out:
# columns available: ['Car_ID', 'Brand', 'Model_Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Engine_CC', 'Max_Power_bhp', 'Mileage_kmpl', 'Seats', 'Price']
# Car_ID               0
# Brand                0
# Model_Year           0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Engine_CC            0
# Max_Power_bhp        0
# Mileage_kmpl         0
# Seats                0
# Price                0
# dtype: int64

# %%
car_df[['Price','Seats','Kilometers_Driven','Engine_CC','Max_Power_bhp','Mileage_kmpl']].describe()
# Out:
#                Price        Seats  Kilometers_Driven    Engine_CC  \
# count    1000.000000  1000.000000        1000.000000  1000.000000
# mean    59217.249420     4.665000      103397.074000  2878.299000
# std     33545.254183     1.802783       57417.612935  1212.337697
# min      3028.420000     2.000000        5155.000000   801.000000
# 25%     30030.822500     4.000000       52188.500000  1818.250000
# 50%     56806.745000     5.000000      102449.000000  2857.500000
# 75%     87088.897500     6.000000      152696.500000  3959.500000
# max    119611.940000     7.000000      199812.000000  4996.000000
#
#        Max_Power_bhp  Mileage_kmpl
# count    1000.000000    1000.00000
# mean      320.939900      17.34144
# std       160.384514       7.29799
# min        40.500000       5.04000
# 25%       184.825000      10.97000
# 50%       314.650000      17.14500
# 75%       455.300000      24.03500
# max       599.600000      29.99000

# %%
car_df[car_df['Seats'] ==2].groupby('Brand').agg({
    'Price': ['mean', 'min', 'max'],
    'Kilometers_Driven': ['mean', 'min', 'max']
})
# Out:
#                    Price                      Kilometers_Driven
#                     mean       min        max              mean    min     max
# Brand
# Audi        66751.641429  15785.70  115645.82      96226.523810  24169  187503
# BMW         44885.609565   3794.22  104684.59     112005.739130  19849  199812
# Ford        61756.088800  10200.53  119533.50      80173.840000  10906  177927
# Honda       48916.211481   3988.83  110006.38     106451.962963  11548  195864
# Hyundai     60042.669167   8237.90  117136.70     113014.541667   9135  197660
# Kia         52831.907917   4248.40  114260.14     116677.041667  20282  194784
# Mercedes    65456.741600   5101.07  115230.55     104542.880000  10469  192686
# Nissan      62951.544286   3274.65  112611.85     104156.809524   8471  198718
# Toyota      58207.239091   4522.19  116857.93     107462.454545  15382  195546
# Volkswagen  60996.445714   3028.42  119485.69     118146.476190   8754  199509

# %%
car_df[car_df['Seats'] ==7].groupby('Brand').agg({
    'Price': ['mean', 'min', 'max'],
    'Kilometers_Driven': ['mean', 'min', 'max']
})
# Out:
#                    Price                      Kilometers_Driven
#                     mean       min        max              mean    min     max
# Brand
# Audi        60951.778182   7718.63  118402.94      98005.545455  12099  195736
# BMW         49625.211579  13015.15  108447.33      99386.526316   5781  195135
# Ford        67731.188696  11297.19  115124.34     104616.478261  32605  186098
# Honda       53532.474000   3435.20  106546.79     114234.600000  13438  196775
# Hyundai     54146.161111  13663.07  117735.84     123137.111111  11823  187684
# Kia         58672.227200  14788.08  114174.71     101579.960000  10782  197404
# Mercedes    72723.186500   7718.05  118345.44     111872.600000   5163  193978
# Nissan      64325.057143   6606.48  103904.79      80326.428571   7336  158741
# Toyota      53954.261429  14203.24  105206.00      97735.523810   8631  193490
# Volkswagen  59105.469524   5386.99  116595.85     117763.476190  22073  196675

# %%
# car_df.columns
# 'Car_ID', 'Brand', 'Model_Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Engine_CC', 'Max_Power_bhp',
#        'Mileage_kmpl', 'Seats', 'Price'

# based on above col - create 10 questions
# Q) What is the average price of cars by brand?
# Q) How does the mileage vary across different fuel types?
# Q) What is the distribution of engine capacities among different brands?
# Q) How many seats do the cars have on average by transmission type?
# Q) What is the relationship between kilometers driven and price?
# Q) How does the maximum power output vary by fuel type?
# Q) What is the average price of cars with 2 seats?
# Q) How does the average mileage compare between petrol and diesel cars?
# Q) What is the trend in car prices over the years?
# Q) How do owner types affect the price of cars?
