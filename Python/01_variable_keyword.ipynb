# %%
age = 24
print(type(age))
age = '24'
print(type(age))
age = 24.5
print(type(age))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
isEligible = True
type(isEligible)


# operation. == 2 number ==> 
age = 24
# what will be age after 10 yrs ( shift + return)
age+10
# Out:
# 34

# %%
# operation. == 2 number ==> 
age = '24'
# what will be age after 10 yrs ( shift + return)
age+10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2 age = '24'
#       3 # what will be age after 10 yrs ( shift + return)
# ----> 4 age+10
#
# TypeError: can only concatenate str (not "int") to str

# %%
# type casting 
# int ---> float
# str ---> int/float
# int/float --->str

age = '24ABC'
# int(age)+ 10
# print(type(age))
# print(age)

# %%
31/17
# Out:
# 1.8235294117647058

# %%
31//17
# Out:
# 1

# %%
31%10
# Out:
# 1
