# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# In-depth exploration of the credit card transactions dataset, focusing on data quality, class imbalance, temporal patterns, user demographics, merchant/category behavior, and distance-based signals.

# %%
# REFER HAND WRITTEN NOTES- BACK OF THE DIARY

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
plt.style.use("seaborn-v0_8")

# %%
# Load raw data
from pathlib import Path

project_root = Path.cwd()

if project_root.name == "projects":
    project_root = project_root.parent

data_path = project_root / "data" / "fraudTest.csv"

raw = pd.read_csv(data_path)
# print(raw)
# Remove index-like column if present
if "Unnamed: 0" in raw.columns:
    raw = raw.drop(columns=["Unnamed: 0"])

raw.head()
# Out:
#   trans_date_trans_time            cc_num  \
# 0   2020-06-21 12:14:25  2291163933867244
# 1   2020-06-21 12:14:33  3573030041201292
# 2   2020-06-21 12:14:53  3598215285024754
# 3   2020-06-21 12:15:15  3591919803438423
# 4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street        city state    zip  \
# 0   Elliott      M            351 Darlene Green    Columbia    SC  29209
# 1  Williams      F             3638 Marsh Union     Altonah    UT  84002
# 2     Lopez      F         9333 Valentine Point    Bellmore    NY  11710
# 3  Williams      M  32941 Krystal Mill Apt. 552  Titusville    FL  32780
# 4    Massey      M     5783 Evan Roads Apt. 465    Falmouth    MI  49632
#
#        lat      long  city_pop                     job         dob  \
# 0  33.9659  -80.9355    333497     Mechanical engineer  1968-03-19
# 1  40.3207 -110.4360       302  Sales professional, IT  1990-01-17
# 2  40.6729  -73.5365     34496       Librarian, public  1970-10-21
# 3  28.5697  -80.8191     54767            Set designer  1987-07-25
# 4  44.2529  -85.0170      1126      Furniture designer  1955-07-06
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  2da90c7d74bd46a0caf3777415b3ebd3  1371816865  33.986391  -81.200714
# 1  324cc204407e99f51b0d6ca0055005e7  1371816873  39.450498 -109.960431
# 2  c81755dbbbea9d5c77f094348a7579be  1371816893  40.495810  -74.196111
# 3  2159175b9efe66dc301f149d3d5abf8c  1371816915  28.812398  -80.883061
# 4  57ff021bd3f328f8738bb535c302a31b  1371816917  44.959148  -85.884734
#
#    is_fraud
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
# Basic overview
# print(raw.shape)
print("Rows:", raw.shape[0])
print("Columns:", raw.shape[1])

raw.info()
# Out:
# Rows: 555719
# Columns: 22
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   trans_date_trans_time  555719 non-null  object
#  1   cc_num                 555719 non-null  int64
#  2   merchant               555719 non-null  object
#  3   category               555719 non-null  object
#  4   amt                    555719 non-null  float64
#  5   first                  555719 non-null  object
#  6   last                   555719 non-null  object
#  7   gender                 555719 non-null  object
#  8   street                 555719 non-null  object
#  9   city                   555719 non-null  object
#  10  state                  555719 non-null  object
#  11  zip                    555719 non-null  int64
#  12  lat                    555719 non-null  float64
#  13  long                   555719 non-null  float64
#  14  city_pop               555719 non-null  int64
#  15  job                    555719 non-null  object
#  16  dob                    555719 non-null  object
#  17  trans_num              555719 non-null  object
#  18  unix_time              555719 non-null  int64
#  19  merch_lat              555719 non-null  float64
#  20  merch_long             555719 non-null  float64
#  21  is_fraud               555719 non-null  int64
# dtypes: float64(5), int64(5), object(12)
# memory usage: 93.3+ MB

# %%
# Missing values and duplicates
missing_values = raw.isnull().sum()
print("\nMissing values per column:\n", missing_values)
missing_values[missing_values > 0]

# NOTE - Common ways to handle missing values

#  A. Drop missing values (only if few)
# Fill (impute) missing values
#  B. Numerical: mean/median/ mode
#  C. Categorical: mode or new category
#  D. Advanced: predictive modeling
    # KNN Imputer
    # Regression Imputation
    # MICE

# Best practice in ML projects
    # Never drop target rows blindly
    # Fit imputers only on training data
    # Save imputation logic for inference
# Out:
# Missing values per column:
#  trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64
# Series([], dtype: int64)

# %%
dup_count = raw.duplicated().sum()
print("Duplicate rows:", dup_count)


# df = df.drop_duplicates()
# Out:
# Duplicate rows: 0

# %%
raw.head()
# Out:
#   trans_date_trans_time            cc_num  \
# 0   2020-06-21 12:14:25  2291163933867244
# 1   2020-06-21 12:14:33  3573030041201292
# 2   2020-06-21 12:14:53  3598215285024754
# 3   2020-06-21 12:15:15  3591919803438423
# 4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street        city state    zip  \
# 0   Elliott      M            351 Darlene Green    Columbia    SC  29209
# 1  Williams      F             3638 Marsh Union     Altonah    UT  84002
# 2     Lopez      F         9333 Valentine Point    Bellmore    NY  11710
# 3  Williams      M  32941 Krystal Mill Apt. 552  Titusville    FL  32780
# 4    Massey      M     5783 Evan Roads Apt. 465    Falmouth    MI  49632
#
#        lat      long  city_pop                     job         dob  \
# 0  33.9659  -80.9355    333497     Mechanical engineer  1968-03-19
# 1  40.3207 -110.4360       302  Sales professional, IT  1990-01-17
# 2  40.6729  -73.5365     34496       Librarian, public  1970-10-21
# 3  28.5697  -80.8191     54767            Set designer  1987-07-25
# 4  44.2529  -85.0170      1126      Furniture designer  1955-07-06
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  2da90c7d74bd46a0caf3777415b3ebd3  1371816865  33.986391  -81.200714
# 1  324cc204407e99f51b0d6ca0055005e7  1371816873  39.450498 -109.960431
# 2  c81755dbbbea9d5c77f094348a7579be  1371816893  40.495810  -74.196111
# 3  2159175b9efe66dc301f149d3d5abf8c  1371816915  28.812398  -80.883061
# 4  57ff021bd3f328f8738bb535c302a31b  1371816917  44.959148  -85.884734
#
#    is_fraud
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
# Class balance
fraud_counts = raw["is_fraud"].value_counts()
fraud_rate = raw["is_fraud"].mean()
print(fraud_counts)
print("Fraud rate:", round(float(fraud_rate), 6))
# NOTE Handling class imbalance - EDA Stage
# 1️⃣ Quantify the imbalance
# 2️⃣ Visualize the imbalance
# 3️⃣ Check business impact
# 4️⃣ Plan mitigation (don’t apply yet in EDA)
    # Document strategies:
    # Class weighting
    # Oversampling (SMOTE)
    # Undersampling
    # Threshold tuning
    # ⚠️ These are applied during modeling, not raw EDA.
# 5️⃣ Choose the right evaluation metrics
    # Avoid accuracy.
    # Use:
    # Precision / Recall
    # F1-score
    # ROC-AUC / PR-AUC
sns.countplot(x="is_fraud", data=raw)
plt.title("Fraud vs Non-Fraud Transactions")
plt.xlabel("Is Fraud")
plt.ylabel("Count")
plt.show()
# Out:
# is_fraud
# 0    553574
# 1      2145
# Name: count, dtype: int64
# Fraud rate: 0.00386

# %%
# Convert time columns
raw["trans_date_trans_time"] = pd.to_datetime(raw["trans_date_trans_time"])
raw["dob"] = pd.to_datetime(raw["dob"])

raw["trans_hour"] = raw["trans_date_trans_time"].dt.hour
raw["trans_dayofweek"] = raw["trans_date_trans_time"].dt.dayofweek
raw["trans_month"] = raw["trans_date_trans_time"].dt.month

raw[["trans_date_trans_time", "trans_hour", "trans_dayofweek", "trans_month"]].head()
# Out:
#   trans_date_trans_time  trans_hour  trans_dayofweek  trans_month
# 0   2020-06-21 12:14:25          12                6            6
# 1   2020-06-21 12:14:33          12                6            6
# 2   2020-06-21 12:14:53          12                6            6
# 3   2020-06-21 12:15:15          12                6            6
# 4   2020-06-21 12:15:17          12                6            6

# %%
# Age feature
raw["age"] = ((raw["trans_date_trans_time"] - raw["dob"]).dt.days / 365.25).astype("float")
raw["age"].describe()
# Out:
# count    555719.000000
# mean         46.887987
# std          17.431204
# min          15.392197
# 25%          33.448323
# 50%          44.908966
# 75%          58.056126
# max          96.169747
# Name: age, dtype: float64

# %%
# Sampling for heavy plots
print(raw.shape)
sample_size = min(200000, len(raw))
raw_sample = raw.sample(sample_size, random_state=42)
raw_sample.shape
# Out:
# (555719, 26)
# (200000, 26)

# %%
raw['amt'].describe()
# Out:
# count    555719.000000
# mean         69.392810
# std         156.745941
# min           1.000000
# 25%           9.630000
# 50%          47.290000
# 75%          83.010000
# max       22768.110000
# Name: amt, dtype: float64

# %%
# Transaction amount distribution
plt.figure(figsize=(8, 4))
sns.histplot(raw_sample["amt"], bins=60, kde=True)
plt.title("Transaction Amount Distribution")
plt.xlabel("Amount")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(8, 4))
sns.histplot(np.log1p(raw_sample["amt"]), bins=60, kde=True)
plt.title("Log-Scaled Transaction Amount Distribution")
plt.xlabel("log(1 + Amount)")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(6, 4))
sns.boxplot(x="is_fraud", y="amt", data=raw_sample)
plt.title("Amount by Fraud Label")
plt.xlabel("Is Fraud")
plt.ylabel("Amount")
plt.show()

# %%
# Fraud rate by amount bins
amt_bins = pd.qcut(raw["amt"], q=10, duplicates="drop")

fraud_by_amt = raw.groupby(amt_bins)["is_fraud"].mean()
print(fraud_by_amt)
plt.figure(figsize=(9, 4))
fraud_by_amt.plot(kind="bar")
plt.title("Fraud Rate by Amount Decile")
plt.xlabel("Amount Decile")
plt.ylabel("Fraud Rate")
plt.xticks(rotation=45, ha="right")
plt.show()
# Out:
# /var/folders/yj/s50h6vr904g40s1wx0dgqpq00000gn/T/ipykernel_16891/371412272.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fraud_by_amt = raw.groupby(amt_bins)["is_fraud"].mean()
# amt
# (0.999, 4.08]         0.000072
# (4.08, 7.72]          0.000684
# (7.72, 15.69]         0.003494
# (15.69, 31.95]        0.003814
# (31.95, 47.29]        0.000018
# (47.29, 60.83]        0.000504
# (60.83, 74.95]        0.000000
# (74.95, 94.4]         0.000018
# (94.4, 135.55]        0.000738
# (135.55, 22768.11]    0.029260
# Name: is_fraud, dtype: float64

# %%
# raw[["trans_date_trans_time", "trans_hour", "trans_dayofweek", "trans_month"]].head()
raw_sample["trans_hour"].head()
# Out:
# 119106     7
# 179292    14
# 540729    16
# 374360    10
# 314574     1
# Name: trans_hour, dtype: int32

# %%
# Time-based patterns
plt.figure(figsize=(8, 4))
sns.countplot(x="trans_hour", data=raw_sample)
plt.title("Transactions by Hour")
plt.xlabel("Hour")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(8, 4))
raw.groupby("trans_hour")["is_fraud"].mean().plot(kind="bar")
plt.title("Fraud Rate by Hour")
plt.xlabel("Hour")
plt.ylabel("Fraud Rate")
plt.show()

plt.figure(figsize=(8, 4))
raw.groupby("trans_dayofweek")["is_fraud"].mean().plot(kind="bar")
plt.title("Fraud Rate by Day of Week")
plt.xlabel("Day of Week (0=Mon)")
plt.ylabel("Fraud Rate")
plt.show()

# %%
# Distance feature (Haversine) between customer and merchant

def haversine(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2) ** 2
    c = 2 * np.arcsin(np.sqrt(a))
    return 6371 * c

raw["distance_km"] = haversine(raw["lat"], raw["long"], raw["merch_lat"], raw["merch_long"])
raw["distance_km"].describe()

plt.figure(figsize=(8, 4))
sns.histplot(raw["distance_km"], bins=60, kde=True)
plt.title("Distance between Customer and Merchant")
plt.xlabel("Distance (km)")
plt.ylabel("Frequency")
plt.show()

# %%
# Fraud rate by distance bins
valid_dist = raw["distance_km"].replace([np.inf, -np.inf], np.nan).dropna()
# print(valid_dist.index)
dist_bins = pd.qcut(valid_dist, q=10, duplicates="drop")
fraud_by_dist = raw.loc[valid_dist.index].groupby(dist_bins)["is_fraud"].mean()

plt.figure(figsize=(9, 4))
fraud_by_dist.plot(kind="bar")
plt.title("Fraud Rate by Distance Decile")
plt.xlabel("Distance Decile")
plt.ylabel("Fraud Rate")
plt.xticks(rotation=45, ha="right")
plt.show()
# Out:
# /var/folders/yj/s50h6vr904g40s1wx0dgqpq00000gn/T/ipykernel_16891/1047709392.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fraud_by_dist = raw.loc[valid_dist.index].groupby(dist_bins)["is_fraud"].mean()

# %%
# Age-based analysis
age_bins = pd.cut(raw["age"], bins=[18, 25, 35, 45, 55, 65, 75, 90])
# age_bins = pd.qcut(raw["age"], q=10, duplicates="drop")
fraud_by_age = raw.groupby(age_bins)["is_fraud"].mean()

plt.figure(figsize=(8, 4))
fraud_by_age.plot(kind="bar")
plt.title("Fraud Rate by Age Bin")
plt.xlabel("Age Bin")
plt.ylabel("Fraud Rate")
plt.xticks(rotation=45, ha="right")
plt.show()
# Out:
# /var/folders/yj/s50h6vr904g40s1wx0dgqpq00000gn/T/ipykernel_16891/2578081076.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fraud_by_age = raw.groupby(age_bins)["is_fraud"].mean()

# %%
# Categorical feature cardinality
categorical_cols = raw.select_dtypes(include=["object"]).columns
print(categorical_cols)
pd.DataFrame({
    "feature": categorical_cols,
    "unique_values": [raw[col].nunique() for col in categorical_cols],
}).sort_values(by="unique_values", ascending=False)
# Out:
# Index(['merchant', 'category', 'first', 'last', 'gender', 'street', 'city',
#        'state', 'job', 'trans_num'],
#       dtype='object')
#      feature  unique_values
# 9  trans_num         555719
# 5     street            924
# 6       city            849
# 0   merchant            693
# 8        job            478
# 3       last            471
# 2      first            341
# 7      state             50
# 1   category             14
# 4     gender              2

# %%
# Fraud rate for categories with enough volume

def fraud_rate_by_category(df, col, min_count=1000):
    counts = df[col].value_counts()
    # print(counts)
    # print(counts[counts >= min_count].index)
    keep = counts[counts >= min_count].index
    # print(df[col].isin(keep))
    rates = df[df[col].isin(keep)].groupby(col)["is_fraud"].mean().sort_values(ascending=False)
    return rates

for col in ["category", "merchant", "job", "state", "city"]:
    rates = fraud_rate_by_category(raw, col, min_count=500)
    print(f"Top fraud rates for {col} (min 500 rows):")
    print(rates.head(10))
# Out:
# Top fraud rates for category (min 500 rows):
# category
# shopping_net     0.012111
# misc_net         0.009756
# grocery_pos      0.009229
# shopping_pos     0.004278
# gas_transport    0.002732
# travel           0.002292
# grocery_net      0.002111
# misc_pos         0.002082
# personal_care    0.001780
# entertainment    0.001471
# Name: is_fraud, dtype: float64
# Top fraud rates for merchant (min 500 rows):
# merchant
# fraud_Romaguera, Cruickshank and Greenholt    0.021739
# fraud_Lemke-Gutmann                           0.021505
# fraud_Mosciski, Ziemann and Farrell           0.020690
# fraud_Heathcote, Yost and Kertzmann           0.020482
# fraud_Rodriguez, Yost and Jenkins             0.019960
# fraud_Medhurst PLC                            0.019430
# fraud_Bashirian Group                         0.018987
# fraud_Kris-Weimann                            0.018939
# fraud_Heathcote LLC                           0.018703
# fraud_Bednar Group                            0.018519
# Name: is_fraud, dtype: float64
# Top fraud rates for job (min 500 rows):
# job
# Commissioning editor                0.035294
# Advertising account executive       0.026562
# Higher education careers adviser    0.023460
# Optometrist                         0.022222
# Licensed conveyancer                0.021970
# Teaching laboratory technician      0.021708
# Psychiatric nurse                   0.021605
# Art therapist                       0.019518
# Architect                           0.016892
# Colour technologist                 0.016667
# Name: is_fraud, dtype: float64
# Top fraud rates for state (min 500 rows):
# state
# AK    0.016607
# CT    0.012206
# ID    0.008835
# HI    0.008257
# MT    0.007324
# DC    0.006592
# IN    0.006271
# OR    0.006145
# MS    0.006113
# VA    0.005997
# Name: is_fraud, dtype: float64
# Top fraud rates for city (min 500 rows):
# city
# Burrton           0.037773
# Camden            0.023622
# Bristol           0.021802
# Viola             0.021605
# Turner            0.020990
# Port Ewen         0.019374
# Coyle             0.019288
# Des Moines        0.018377
# Cazenovia         0.018377
# Grand Junction    0.018349
# Name: is_fraud, dtype: float64

# %%
# Numeric correlations
numeric_cols = raw.select_dtypes(include=["number"]).columns
corr = raw[numeric_cols].corr()

plt.figure(figsize=(11, 9))
sns.heatmap(corr, cmap="coolwarm", center=0)
plt.title("Numeric Feature Correlations")
plt.show()
# Note: Correlation does not imply causation. Further analysis is needed to establish causal relationships.

# %%
# Point-biserial correlation with target
from scipy.stats import pointbiserialr

pb_results = []
for col in numeric_cols:
    if col == "is_fraud":
        continue
    clean = raw[[col, "is_fraud"]].dropna()
    if clean[col].nunique() > 1:
        r, p = pointbiserialr(clean["is_fraud"], clean[col])
        pb_results.append((col, r, p))

pb_df = pd.DataFrame(pb_results, columns=["feature", "r", "p_value"]).sort_values(by="r", ascending=False)
pb_df.head(15)

# Point-biserial correlation measures the relationship between:
    # One continuous variable (e.g., age, income, score)
    # One binary variable (target) coded as 0/1
# Out:
#             feature         r       p_value
# 1               amt  0.182267  0.000000e+00
# 9        trans_hour  0.011686  2.999880e-18
# 10  trans_dayofweek  0.009365  2.925734e-12
# 12              age  0.007457  2.717840e-08
# 3               lat  0.005863  1.238354e-05
# 7         merch_lat  0.005812  1.471158e-05
# 13      distance_km  0.000233  8.620877e-01
# 4              long -0.000972  4.687723e-01
# 8        merch_long -0.001060  4.294427e-01
# 0            cc_num -0.001540  2.508703e-01
# 2               zip -0.002271  9.047615e-02
# 5          city_pop -0.004910  2.522176e-04
# 11      trans_month -0.011748  1.989832e-18
# 6         unix_time -0.013066  2.022592e-22

# %%
# Select required columns
new_df = raw[["amt", "category", "gender", "is_fraud", "state", "city_pop", "job", "distance_km", "age", "trans_hour", "trans_dayofweek", "trans_month"]]

# Save to CSV
new_df.to_csv("processed_credit_data.csv", index=False)

# %% [markdown]
# ## Summary
#
# - The dataset is highly imbalanced, so precision/recall and PR-AUC will be more informative than accuracy.
# - Time-of-day, amount, distance, and category/merchant/job patterns show distinct fraud-rate differences.
# - High-cardinality categorical features may need encoding or grouping for modeling.
